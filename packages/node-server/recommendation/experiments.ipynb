# %% [markdown]
# # Cornac recommendation system experiment
# A simple experiment to compare the following recommendation models:
# - Maximum margin matrix factorization (MMMR), [paper](https://papers.nips.cc/paper_files/paper/2004/file/e0688d13958a19e087e123148555e4b4-Paper.pdf)
# - Embarresingly shallow autoencoder (EASE), [paper](https://arxiv.org/pdf/1905.03375.pdf)
# - Bayesian Personalised Ranking (BPR), [paper](https://arxiv.org/ftp/arxiv/papers/1205/1205.2618.pdf)

# %% [markdown]
# ## Used experiment

# %%
# Installing required modules

# Colab does not cache external modules
# This needs to be run on every colab session
import sys
required_mods = ['cornac']
reinstall = False

for mod in required_mods:
  if not (mod in sys.modules):
    reinstall = True
    break;
    
if (reinstall):
  # %pip install cornac scikit-surprise recommenders
# Out:
# Collecting cornac
#   Downloading cornac-1.15.1-cp39-cp39-manylinux1_x86_64.whl (18.8 MB)
#      |████████████████████████████████| 18.8 MB 9.6 MB/s eta 0:00:01
# Collecting scikit-surprise
#   Downloading scikit-surprise-1.1.3.tar.gz (771 kB)
#      |████████████████████████████████| 771 kB 8.2 MB/s eta 0:00:01
# Collecting recommenders
#   Using cached recommenders-1.1.1-py3-none-any.whl (339 kB)
# Collecting scipy
#   Downloading scipy-1.10.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
#      |████████████████████████████████| 34.5 MB 25 kB/s  eta 0:00:01
# Collecting tqdm>=4.19
#   Downloading tqdm-4.65.0-py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 2.3 MB/s eta 0:00:01
# Collecting powerlaw
#   Using cached powerlaw-1.5-py3-none-any.whl (24 kB)
# Collecting numpy
#   Using cached numpy-1.24.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# Collecting joblib>=1.0.0
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# Collecting scikit-learn<1.0.3,>=0.22.1
#   Downloading scikit_learn-1.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.4 MB)
#      |████████████████████████████████| 26.4 MB 158 kB/s eta 0:00:01
# Collecting jinja2<3.1,>=2
#   Using cached Jinja2-3.0.3-py3-none-any.whl (133 kB)
# Collecting bottleneck<2,>=1.2.1
#   Downloading Bottleneck-1.3.7-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (353 kB)
#      |████████████████████████████████| 353 kB 6.8 MB/s eta 0:00:01
# Collecting nltk<4,>=3.4
#   Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# Collecting memory-profiler<1,>=0.54.0
#   Using cached memory_profiler-0.61.0-py3-none-any.whl (31 kB)
# Collecting pandera[strategies]>=0.6.5
#   Downloading pandera-0.14.5-py3-none-any.whl (149 kB)
#      |████████████████████████████████| 149 kB 5.3 MB/s eta 0:00:01
# Collecting pyyaml<6,>=5.4.1
#   Downloading PyYAML-5.4.1-cp39-cp39-manylinux1_x86_64.whl (630 kB)
#      |████████████████████████████████| 630 kB 7.0 MB/s eta 0:00:01
# Collecting requests<3,>=2.0.0
#   Downloading requests-2.29.0-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 659 kB/s eta 0:00:011
# Collecting category-encoders<2,>=1.3.0
#   Using cached category_encoders-1.3.0-py2.py3-none-any.whl (61 kB)
# Collecting matplotlib<4,>=2.2.2
#   Downloading matplotlib-3.7.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      |████████████████████████████████| 11.6 MB 8.2 MB/s eta 0:00:01
# Collecting retrying>=1.3.3
#   Using cached retrying-1.3.4-py3-none-any.whl (11 kB)
# Collecting lightgbm>=2.2.1
#   Using cached lightgbm-3.3.5-py3-none-manylinux1_x86_64.whl (2.0 MB)
# Collecting seaborn<1,>=0.8.1
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      |████████████████████████████████| 293 kB 8.4 MB/s eta 0:00:01
# Collecting lightfm<2,>=1.15
#   Downloading lightfm-1.17.tar.gz (316 kB)
#      |████████████████████████████████| 316 kB 6.7 MB/s eta 0:00:01
# Collecting transformers<5,>=2.5.0
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      |████████████████████████████████| 7.0 MB 1.1 MB/s eta 0:00:01
# Collecting numba<1,>=0.38.1
#   Downloading numba-0.56.4-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.5 MB)
#      |████████████████████████████████| 3.5 MB 8.8 MB/s eta 0:00:01
# Collecting pandas<2,>1.0.3
#   Downloading pandas-1.5.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#      |████████████████████████████████| 12.2 MB 7.3 MB/s eta 0:00:01
# Collecting mpmath
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      |████████████████████████████████| 536 kB 6.7 MB/s eta 0:00:01
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/moorad/.local/lib/python3.9/site-packages (from jinja2<3.1,>=2->recommenders) (2.1.2)
# Collecting regex>=2021.8.3
#   Downloading regex-2023.3.23-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (768 kB)
#      |████████████████████████████████| 768 kB 7.5 MB/s eta 0:00:01
# Collecting click
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Requirement already satisfied: psutil in /home/moorad/.local/lib/python3.9/site-packages (from memory-profiler<1,>=0.54.0->recommenders) (5.9.5)
# Collecting typing-inspect>=0.6.0
#   Using cached typing_inspect-0.8.0-py3-none-any.whl (8.7 kB)
# Collecting pydantic
#   Downloading pydantic-1.10.7-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 6.9 MB/s eta 0:00:01
# Collecting wrapt
#   Downloading wrapt-1.15.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (78 kB)
#      |████████████████████████████████| 78 kB 3.1 MB/s eta 0:00:011
# Collecting multimethod
#   Downloading multimethod-1.9.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: packaging>=20.0 in /home/moorad/.local/lib/python3.9/site-packages (from pandera[strategies]>=0.6.5->recommenders) (23.1)
# Collecting hypothesis>=5.41.1; extra == "strategies"
#   Downloading hypothesis-6.74.0-py3-none-any.whl (409 kB)
#      |████████████████████████████████| 409 kB 8.3 MB/s eta 0:00:01
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.1.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (199 kB)
#      |████████████████████████████████| 199 kB 8.2 MB/s eta 0:00:01
# Collecting certifi>=2017.4.17
#   Using cached certifi-2022.12.7-py3-none-any.whl (155 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.15-py2.py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 8.9 MB/s eta 0:00:01
# Requirement already satisfied: idna<4,>=2.5 in /home/moorad/.local/lib/python3.9/site-packages (from requests<3,>=2.0.0->recommenders) (3.4)
# Collecting patsy>=0.4.1
#   Using cached patsy-0.5.3-py2.py3-none-any.whl (233 kB)
# Collecting statsmodels>=0.6.1
#   Downloading statsmodels-0.13.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 7.7 MB/s eta 0:00:01
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.5.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 8.3 kB/s eta 0:00:01     |███████████████████▍            | 2.0 MB 8.4 MB/s eta 0:00:01
# Collecting importlib-resources>=3.2.0; python_version < "3.10"
#   Downloading importlib_resources-5.12.0-py3-none-any.whl (36 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/moorad/.local/lib/python3.9/site-packages (from matplotlib<4,>=2.2.2->recommenders) (2.8.2)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.39.3-py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 8.1 MB/s eta 0:00:01
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.7-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (299 kB)
#      |████████████████████████████████| 299 kB 6.7 MB/s eta 0:00:01
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 7.5 MB/s eta 0:00:01
# Collecting pyparsing>=2.3.1
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: six>=1.7.0 in /home/moorad/.local/lib/python3.9/site-packages (from retrying>=1.3.3->recommenders) (1.16.0)
# Requirement already satisfied: wheel in /usr/lib/python3/dist-packages (from lightgbm>=2.2.1->recommenders) (0.34.2)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      |████████████████████████████████| 224 kB 8.5 MB/s eta 0:00:01
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      |████████████████████████████████| 7.8 MB 7.4 MB/s eta 0:00:01
# Collecting filelock
#   Downloading filelock-3.12.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from numba<1,>=0.38.1->recommenders) (45.2.0)
# Collecting llvmlite<0.40,>=0.39.0dev0
#   Downloading llvmlite-0.39.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.6 MB)
#      |████████████████████████████████| 34.6 MB 108 kB/s eta 0:00:01
# Collecting pytz>=2020.1
#   Downloading pytz-2023.3-py2.py3-none-any.whl (502 kB)
#      |████████████████████████████████| 502 kB 5.4 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions>=3.7.4 in /home/moorad/.local/lib/python3.9/site-packages (from typing-inspect>=0.6.0->pandera[strategies]>=0.6.5->recommenders) (4.5.0)
# Collecting mypy-extensions>=0.3.0
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting exceptiongroup>=1.0.0; python_version < "3.11"
#   Downloading exceptiongroup-1.1.1-py3-none-any.whl (14 kB)
# Collecting sortedcontainers<3.0.0,>=2.1.0
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: attrs>=19.2.0 in /home/moorad/.local/lib/python3.9/site-packages (from hypothesis>=5.41.1; extra == "strategies"->pandera[strategies]>=0.6.5->recommenders) (23.1.0)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /home/moorad/.local/lib/python3.9/site-packages (from importlib-resources>=3.2.0; python_version < "3.10"->matplotlib<4,>=2.2.2->recommenders) (3.15.0)
# Collecting fsspec
#   Downloading fsspec-2023.4.0-py3-none-any.whl (153 kB)
#      |████████████████████████████████| 153 kB 7.6 MB/s eta 0:00:01
# Building wheels for collected packages: scikit-surprise, lightfm
#   Building wheel for scikit-surprise (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /bin/python3.9 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-gp8cf9sl/scikit-surprise/setup.py'"'"'; __file__='"'"'/tmp/pip-install-gp8cf9sl/scikit-surprise/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-fvd563q3
#        cwd: /tmp/pip-install-gp8cf9sl/scikit-surprise/
#   Complete output (56 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.linux-x86_64-3.9
#   creating build/lib.linux-x86_64-3.9/surprise
#   copying surprise/__main__.py -> build/lib.linux-x86_64-3.9/surprise
#   copying surprise/utils.py -> build/lib.linux-x86_64-3.9/surprise
#   copying surprise/builtin_datasets.py -> build/lib.linux-x86_64-3.9/surprise
#   copying surprise/trainset.py -> build/lib.linux-x86_64-3.9/surprise
#   copying surprise/reader.py -> build/lib.linux-x86_64-3.9/surprise
#   copying surprise/accuracy.py -> build/lib.linux-x86_64-3.9/surprise
#   copying surprise/dataset.py -> build/lib.linux-x86_64-3.9/surprise
#   copying surprise/dump.py -> build/lib.linux-x86_64-3.9/surprise
#   copying surprise/__init__.py -> build/lib.linux-x86_64-3.9/surprise
#   creating build/lib.linux-x86_64-3.9/surprise/model_selection
#   copying surprise/model_selection/search.py -> build/lib.linux-x86_64-3.9/surprise/model_selection
#   copying surprise/model_selection/validation.py -> build/lib.linux-x86_64-3.9/surprise/model_selection
#   copying surprise/model_selection/split.py -> build/lib.linux-x86_64-3.9/surprise/model_selection
#   copying surprise/model_selection/__init__.py -> build/lib.linux-x86_64-3.9/surprise/model_selection
#   creating build/lib.linux-x86_64-3.9/surprise/prediction_algorithms
#   copying surprise/prediction_algorithms/baseline_only.py -> build/lib.linux-x86_64-3.9/surprise/prediction_algorithms
#   copying surprise/prediction_algorithms/knns.py -> build/lib.linux-x86_64-3.9/surprise/prediction_algorithms
#   copying surprise/prediction_algorithms/algo_base.py -> build/lib.linux-x86_64-3.9/surprise/prediction_algorithms
#   copying surprise/prediction_algorithms/predictions.py -> build/lib.linux-x86_64-3.9/surprise/prediction_algorithms
#   copying surprise/prediction_algorithms/__init__.py -> build/lib.linux-x86_64-3.9/surprise/prediction_algorithms
#   copying surprise/prediction_algorithms/random_pred.py -> build/lib.linux-x86_64-3.9/surprise/prediction_algorithms
#   running egg_info
#   writing scikit_surprise.egg-info/PKG-INFO
#   writing dependency_links to scikit_surprise.egg-info/dependency_links.txt
#   writing entry points to scikit_surprise.egg-info/entry_points.txt
#   writing requirements to scikit_surprise.egg-info/requires.txt
#   writing top-level names to scikit_surprise.egg-info/top_level.txt
#   reading manifest file 'scikit_surprise.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   writing manifest file 'scikit_surprise.egg-info/SOURCES.txt'
#   copying surprise/similarities.c -> build/lib.linux-x86_64-3.9/surprise
#   copying surprise/similarities.pyx -> build/lib.linux-x86_64-3.9/surprise
#   copying surprise/prediction_algorithms/co_clustering.c -> build/lib.linux-x86_64-3.9/surprise/prediction_algorithms
#   copying surprise/prediction_algorithms/co_clustering.pyx -> build/lib.linux-x86_64-3.9/surprise/prediction_algorithms
#   copying surprise/prediction_algorithms/matrix_factorization.c -> build/lib.linux-x86_64-3.9/surprise/prediction_algorithms
#   copying surprise/prediction_algorithms/matrix_factorization.pyx -> build/lib.linux-x86_64-3.9/surprise/prediction_algorithms
#   copying surprise/prediction_algorithms/optimize_baselines.c -> build/lib.linux-x86_64-3.9/surprise/prediction_algorithms
#   copying surprise/prediction_algorithms/optimize_baselines.pyx -> build/lib.linux-x86_64-3.9/surprise/prediction_algorithms
#   copying surprise/prediction_algorithms/slope_one.c -> build/lib.linux-x86_64-3.9/surprise/prediction_algorithms
#   copying surprise/prediction_algorithms/slope_one.pyx -> build/lib.linux-x86_64-3.9/surprise/prediction_algorithms
#   running build_ext
#   building 'surprise.similarities' extension
#   creating build/temp.linux-x86_64-3.9
#   creating build/temp.linux-x86_64-3.9/surprise
#   x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/tmp/pip-install-gp8cf9sl/scikit-surprise/.eggs/numpy-1.24.3-py3.9-linux-x86_64.egg/numpy/core/include -I/usr/include/python3.9 -c surprise/similarities.c -o build/temp.linux-x86_64-3.9/surprise/similarities.o
#   surprise/similarities.c:28:10: fatal error: Python.h: No such file or directory
#      28 | #include "Python.h"
#         |          ^~~~~~~~~~
#   compilation terminated.
#   error: command '/bin/x86_64-linux-gnu-gcc' failed with exit code 1
#   ----------------------------------------
#   ERROR: Failed building wheel for scikit-surprise
#   Running setup.py clean for scikit-surprise
#   Building wheel for lightfm (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /bin/python3.9 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-gp8cf9sl/lightfm/setup.py'"'"'; __file__='"'"'/tmp/pip-install-gp8cf9sl/lightfm/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-mv76rz5o
#        cwd: /tmp/pip-install-gp8cf9sl/lightfm/
#   Complete output (29 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.linux-x86_64-3.9
#   creating build/lib.linux-x86_64-3.9/lightfm
#   copying lightfm/_lightfm_fast.py -> build/lib.linux-x86_64-3.9/lightfm
#   copying lightfm/data.py -> build/lib.linux-x86_64-3.9/lightfm
#   copying lightfm/lightfm.py -> build/lib.linux-x86_64-3.9/lightfm
#   copying lightfm/evaluation.py -> build/lib.linux-x86_64-3.9/lightfm
#   copying lightfm/cross_validation.py -> build/lib.linux-x86_64-3.9/lightfm
#   copying lightfm/__init__.py -> build/lib.linux-x86_64-3.9/lightfm
#   creating build/lib.linux-x86_64-3.9/lightfm/datasets
#   copying lightfm/datasets/movielens.py -> build/lib.linux-x86_64-3.9/lightfm/datasets
#   copying lightfm/datasets/stackexchange.py -> build/lib.linux-x86_64-3.9/lightfm/datasets
#   copying lightfm/datasets/_common.py -> build/lib.linux-x86_64-3.9/lightfm/datasets
#   copying lightfm/datasets/__init__.py -> build/lib.linux-x86_64-3.9/lightfm/datasets
#   copying lightfm/_lightfm_fast_no_openmp.c -> build/lib.linux-x86_64-3.9/lightfm
#   copying lightfm/_lightfm_fast_openmp.c -> build/lib.linux-x86_64-3.9/lightfm
#   running build_ext
#   building 'lightfm._lightfm_fast_openmp' extension
#   creating build/temp.linux-x86_64-3.9
#   creating build/temp.linux-x86_64-3.9/lightfm
#   x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/include/python3.9 -c lightfm/_lightfm_fast_openmp.c -o build/temp.linux-x86_64-3.9/lightfm/_lightfm_fast_openmp.o -ffast-math -march=native -fopenmp
#   lightfm/_lightfm_fast_openmp.c:22:10: fatal error: Python.h: No such file or directory
#      22 | #include "Python.h"
#         |          ^~~~~~~~~~
#   compilation terminated.
#   error: command '/bin/x86_64-linux-gnu-gcc' failed with exit code 1
#   ----------------------------------------
#   ERROR: Failed building wheel for lightfm
#   Running setup.py clean for lightfm
# Failed to build scikit-surprise lightfm
# ERROR: numba 0.56.4 has requirement numpy<1.24,>=1.18, but you'll have numpy 1.24.3 which is incompatible.
# Installing collected packages: numpy, scipy, tqdm, mpmath, pillow, importlib-resources, fonttools, contourpy, kiwisolver, pyparsing, cycler, matplotlib, powerlaw, cornac, joblib, scikit-surprise, threadpoolctl, scikit-learn, jinja2, bottleneck, regex, click, nltk, memory-profiler, mypy-extensions, typing-inspect, pydantic, wrapt, pytz, pandas, multimethod, exceptiongroup, sortedcontainers, hypothesis, pandera, pyyaml, charset-normalizer, certifi, urllib3, requests, patsy, statsmodels, category-encoders, retrying, lightgbm, seaborn, lightfm, fsspec, filelock, huggingface-hub, tokenizers, transformers, llvmlite, numba, recommenders
#     Running setup.py install for scikit-surprise ... error
#     ERROR: Command errored out with exit status 1:
#      command: /bin/python3.9 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-gp8cf9sl/scikit-surprise/setup.py'"'"'; __file__='"'"'/tmp/pip-install-gp8cf9sl/scikit-surprise/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-j0gsqho9/install-record.txt --single-version-externally-managed --user --prefix= --compile --install-headers /home/moorad/.local/include/python3.9/scikit-surprise
#          cwd: /tmp/pip-install-gp8cf9sl/scikit-surprise/
#     Complete output (56 lines):
#     running install
#     running build
#     running build_py
#     creating build
#     creating build/lib.linux-x86_64-3.9
#     creating build/lib.linux-x86_64-3.9/surprise
#     copying surprise/__main__.py -> build/lib.linux-x86_64-3.9/surprise
#     copying surprise/utils.py -> build/lib.linux-x86_64-3.9/surprise
#     copying surprise/builtin_datasets.py -> build/lib.linux-x86_64-3.9/surprise
#     copying surprise/trainset.py -> build/lib.linux-x86_64-3.9/surprise
#     copying surprise/reader.py -> build/lib.linux-x86_64-3.9/surprise
#     copying surprise/accuracy.py -> build/lib.linux-x86_64-3.9/surprise
#     copying surprise/dataset.py -> build/lib.linux-x86_64-3.9/surprise
#     copying surprise/dump.py -> build/lib.linux-x86_64-3.9/surprise
#     copying surprise/__init__.py -> build/lib.linux-x86_64-3.9/surprise
#     creating build/lib.linux-x86_64-3.9/surprise/model_selection
#     copying surprise/model_selection/search.py -> build/lib.linux-x86_64-3.9/surprise/model_selection
#     copying surprise/model_selection/validation.py -> build/lib.linux-x86_64-3.9/surprise/model_selection
#     copying surprise/model_selection/split.py -> build/lib.linux-x86_64-3.9/surprise/model_selection
#     copying surprise/model_selection/__init__.py -> build/lib.linux-x86_64-3.9/surprise/model_selection
#     creating build/lib.linux-x86_64-3.9/surprise/prediction_algorithms
#     copying surprise/prediction_algorithms/baseline_only.py -> build/lib.linux-x86_64-3.9/surprise/prediction_algorithms
#     copying surprise/prediction_algorithms/knns.py -> build/lib.linux-x86_64-3.9/surprise/prediction_algorithms
#     copying surprise/prediction_algorithms/algo_base.py -> build/lib.linux-x86_64-3.9/surprise/prediction_algorithms
#     copying surprise/prediction_algorithms/predictions.py -> build/lib.linux-x86_64-3.9/surprise/prediction_algorithms
#     copying surprise/prediction_algorithms/__init__.py -> build/lib.linux-x86_64-3.9/surprise/prediction_algorithms
#     copying surprise/prediction_algorithms/random_pred.py -> build/lib.linux-x86_64-3.9/surprise/prediction_algorithms
#     running egg_info
#     writing scikit_surprise.egg-info/PKG-INFO
#     writing dependency_links to scikit_surprise.egg-info/dependency_links.txt
#     writing entry points to scikit_surprise.egg-info/entry_points.txt
#     writing requirements to scikit_surprise.egg-info/requires.txt
#     writing top-level names to scikit_surprise.egg-info/top_level.txt
#     reading manifest file 'scikit_surprise.egg-info/SOURCES.txt'
#     reading manifest template 'MANIFEST.in'
#     writing manifest file 'scikit_surprise.egg-info/SOURCES.txt'
#     copying surprise/similarities.c -> build/lib.linux-x86_64-3.9/surprise
#     copying surprise/similarities.pyx -> build/lib.linux-x86_64-3.9/surprise
#     copying surprise/prediction_algorithms/co_clustering.c -> build/lib.linux-x86_64-3.9/surprise/prediction_algorithms
#     copying surprise/prediction_algorithms/co_clustering.pyx -> build/lib.linux-x86_64-3.9/surprise/prediction_algorithms
#     copying surprise/prediction_algorithms/matrix_factorization.c -> build/lib.linux-x86_64-3.9/surprise/prediction_algorithms
#     copying surprise/prediction_algorithms/matrix_factorization.pyx -> build/lib.linux-x86_64-3.9/surprise/prediction_algorithms
#     copying surprise/prediction_algorithms/optimize_baselines.c -> build/lib.linux-x86_64-3.9/surprise/prediction_algorithms
#     copying surprise/prediction_algorithms/optimize_baselines.pyx -> build/lib.linux-x86_64-3.9/surprise/prediction_algorithms
#     copying surprise/prediction_algorithms/slope_one.c -> build/lib.linux-x86_64-3.9/surprise/prediction_algorithms
#     copying surprise/prediction_algorithms/slope_one.pyx -> build/lib.linux-x86_64-3.9/surprise/prediction_algorithms
#     running build_ext
#     building 'surprise.similarities' extension
#     creating build/temp.linux-x86_64-3.9
#     creating build/temp.linux-x86_64-3.9/surprise
#     x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/home/moorad/.local/lib/python3.9/site-packages/numpy/core/include -I/usr/include/python3.9 -c surprise/similarities.c -o build/temp.linux-x86_64-3.9/surprise/similarities.o
#     surprise/similarities.c:28:10: fatal error: Python.h: No such file or directory
#        28 | #include "Python.h"
#           |          ^~~~~~~~~~
#     compilation terminated.
#     error: command '/bin/x86_64-linux-gnu-gcc' failed with exit code 1
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: /bin/python3.9 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-gp8cf9sl/scikit-surprise/setup.py'"'"'; __file__='"'"'/tmp/pip-install-gp8cf9sl/scikit-surprise/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-j0gsqho9/install-record.txt --single-version-externally-managed --user --prefix= --compile --install-headers /home/moorad/.local/include/python3.9/scikit-surprise Check the logs for full command output.
# Note: you may need to restart the kernel to use updated packages.

# %%
import cornac
from cornac.data import Reader
from cornac.datasets import movielens
from cornac.eval_methods import RatioSplit

# Import dataset and convert to implicit feedback
feedback = movielens.load_feedback(variant="1M", reader=Reader(bin_threshold=1.0))

# Define an evaluation method to split feedback into train and test sets
ratio_split = RatioSplit(
    data=feedback,
    test_size=0.2,
    rating_threshold=1.0,
    exclude_unknowns=True,
    verbose=True,
)

# Define models and hyperparameters
most_pop = cornac.models.MostPop() 
mmmf = mmmf = cornac.models.MMMF(k=10, max_iter=200, learning_rate=0.01, verbose=True)
ease = cornac.models.EASE(
    lamb=500,
    name="EASEᴿ (B>0)",
    posB=True
)
bpr = cornac.models.BPR(
    k=50, max_iter=200, learning_rate=0.001, lambda_reg=0.001, verbose=True
)


# Use RMSE and DCG (N=10)
recall = cornac.metrics.Recall(k=10)
ndcg = cornac.metrics.NDCG(k=10)

# Perform the experiment
cornac.Experiment(
    eval_method=ratio_split,
    models=[most_pop, mmmf, ease,bpr],
    metrics=[recall, ndcg],
    user_based=True,
).run()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_3828/4242675877.py in <module>
# ----> 1 import cornac
#       2 from cornac.data import Reader
#       3 from cornac.datasets import movielens
#       4 from cornac.eval_methods import RatioSplit
#       5
#
# ~/.local/lib/python3.7/site-packages/cornac/__init__.py in <module>
#      14 # ============================================================================
#      15
# ---> 16 from . import data
#      17 from . import datasets
#      18 from . import eval_methods
#
# ~/.local/lib/python3.7/site-packages/cornac/data/__init__.py in <module>
#      16 from .modality import Modality
#      17 from .modality import FeatureModality
# ---> 18 from .text import TextModality, ReviewModality
#      19 from .image import ImageModality
#      20 from .graph import GraphModality
#
# ~/.local/lib/python3.7/site-packages/cornac/data/text.py in <module>
#      25 from . import FeatureModality
#      26 from .modality import fallback_feature
# ---> 27 from ..utils import normalize
#      28
#      29 __all__ = ['Tokenizer',
#
# ~/.local/lib/python3.7/site-packages/cornac/utils/__init__.py in <module>
#      14 # ============================================================================
#      15
# ---> 16 from .common import validate_format
#      17 from .common import estimate_batches
#      18 from .common import get_rng
#
# ~/.local/lib/python3.7/site-packages/cornac/utils/common.py in <module>
#      19 import scipy.sparse as sp
#      20
# ---> 21 from .fast_sparse_funcs import (
#      22     inplace_csr_row_normalize_l1,
#      23     inplace_csr_row_normalize_l2
#
# ImportError: libpython3.7m.so.1.0: cannot open shared object file: No such file or directory

# %% [markdown]
# ## Other (failed) experiments

# %%
# Installing required modules

# Colab does not cache external modules
# This needs to be run on every colab session
import sys
required_mods = ['cornac', 'recommenders', 'surprise']
reinstall = False

for mod in required_mods:
  if not (mod in sys.modules):
    reinstall = True
    break;
    
if (reinstall):
  # %pip install cornac scikit-surprise recommenders

# %%
import cornac
import surprise
from recommenders.datasets import movielens
from recommenders.utils.constants import SEED
from recommenders.utils.timer import Timer
from recommenders.models.cornac.cornac_utils import predict_ranking
from recommenders.models.surprise.surprise_utils import surprise_trainset_to_df, predict, compute_ranking_predictions
from recommenders.evaluation.python_evaluation import rmse, ndcg_at_k
from sklearn.model_selection import train_test_split

# %%
# Configuration

# Convert explicit ratings (1-5) to implicit binary rating
implicit_ratings = False;
training_split = 0.75;

# Number of recommendations for each user (evaluation) 
k = 10

# %%
# Import movielens dataset
data = movielens.load_pandas_df(size='100k', header=['userID', 'itemID', 'rating'])
data.head()
# Out:
# 100%|██████████| 4.81k/4.81k [00:00<00:00, 10.8kKB/s]
#    userID  itemID  rating
# 0     196     242     3.0
# 1     186     302     3.0
# 2      22     377     1.0
# 3     244      51     2.0
# 4     166     346     1.0

# %%
# Convert explicit rating to implicit ratings
if (implicit_ratings):
  data.rating = data.rating.map(lambda x: 1 if x > 3 else 0) 

data.head()
# Out:
#    userID  itemID  rating
# 0     196     242     3.0
# 1     186     302     3.0
# 2      22     377     1.0
# 3     244      51     2.0
# 4     166     346     1.0

# %%
# Split dataset to training and testing set. 75/25
train, test = train_test_split(data, train_size=training_split)

train.shape
# Out:
# (75000, 3)

# %% [markdown]
# ### Suprise Recommenders

# %%
# Convert surprise reader to binary rating scale if implicit ratings
reader = surprise.Reader(rating_scale = (1,5))

if (implicit_ratings):
  reader = surprise.Reader(rating_scale = (0,1))

# %%
# Convert train dataset to surprise dataset
trainset = surprise.Dataset.load_from_df(train , reader=reader).build_full_trainset()

trainset

# %% [markdown]
# #### SVD
# Works on explicit feedback only so this cannot be used for the project + was designed and performs extremely well on single item recommendations (apparent from the RMSE), bad at top-n recommendation

# %%
# Hyperparameters
n_factors = 20
n_epochs = 30

# %%
# Train
svd = surprise.SVD(random_state=0, n_factors=n_factors, n_epochs=n_epochs, verbose=True)

with Timer() as train_time:
    svd.fit(trainset)

print(f"Training took {train_time.interval} seconds")
# Out:
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# Processing epoch 20
# Processing epoch 21
# Processing epoch 22
# Processing epoch 23
# Processing epoch 24
# Processing epoch 25
# Processing epoch 26
# Processing epoch 27
# Processing epoch 28
# Processing epoch 29
# Training took 2.361976502999994 seconds

# %%
# View results
predictions = predict(svd, test, usercol='userID', itemcol='itemID')

predictions.head()
# Out:
#    userID  itemID  prediction
# 0     535     699    3.915372
# 1     732     332    3.846788
# 2     559     385    3.470695
# 3     378     473    3.070922
# 4      23      28    3.800569

# %%
# Test
with Timer() as test_time:
    all_predictions = compute_ranking_predictions(svd, train, usercol='userID', itemcol='itemID', remove_seen=True)
    
print(f"Testing took {test_time.interval} seconds")
# Out:
# Testing took 34.02148172100004 seconds

# %%
# Evaluate
eval_rmse = rmse(test, predictions)
eval_ndcg = ndcg_at_k(test, all_predictions, col_prediction='prediction', k=k)

print("SVD (Surprise) Top@10 results:")
print('----')
print("RMSE:\t%f" % eval_rmse)
print("NDCG:\t%f" % eval_ndcg)
# Out:
# SVD (Surprise) Top@10 results:
# ----
# RMSE:	0.933221
# NDCG:	0.109762

# %% [markdown]
# #### SVD++
# An improved version of SVD that uses both implicit and explicit feedback. It requires explicit feedback to work so it could not be chosen

# %%
# Hyperparameters
n_factors = 20
n_epochs = 30

# %%
# Train
svdpp = surprise.SVDpp(random_state=0, n_factors=n_factors, n_epochs=n_epochs, verbose=True)

with Timer() as train_time:
    svdpp.fit(trainset)

print(f"Training took {train_time.interval} seconds")
# Out:
#  processing epoch 0
#  processing epoch 1
#  processing epoch 2
#  processing epoch 3
#  processing epoch 4
#  processing epoch 5
#  processing epoch 6
#  processing epoch 7
#  processing epoch 8
#  processing epoch 9
#  processing epoch 10
#  processing epoch 11
#  processing epoch 12
#  processing epoch 13
#  processing epoch 14
#  processing epoch 15
#  processing epoch 16
#  processing epoch 17
#  processing epoch 18
#  processing epoch 19
#  processing epoch 20
#  processing epoch 21
#  processing epoch 22
#  processing epoch 23
#  processing epoch 24
#  processing epoch 25
#  processing epoch 26
#  processing epoch 27
#  processing epoch 28
#  processing epoch 29
# Training took 37.12319648700003 seconds

# %%
# View results
predictions = predict(svdpp, test, usercol='userID', itemcol='itemID')

predictions.head()
# Out:
#    userID  itemID  prediction
# 0     535     699    4.386404
# 1     732     332    4.091190
# 2     559     385    3.454677
# 3     378     473    2.952356
# 4      23      28    3.972290

# %%
# Test
with Timer() as test_time:
    all_predictions = compute_ranking_predictions(svdpp, train, usercol='userID', itemcol='itemID', remove_seen=True)
    
print(f"Testing took {test_time.interval} seconds")
# Out:
# Testing took 225.36368552300002 seconds

# %%
# Evaluate
eval_rmse = rmse(test, predictions)
eval_ndcg = ndcg_at_k(test, all_predictions, col_prediction='prediction', k=k)

print("SVD++ (Surprise) Top@10 results:")
print('----')
print("RMSE:\t%f" % eval_rmse)
print("NDCG:\t%f" % eval_ndcg)
# Out:
# SVD++ (Surprise) Top@10 results:
# ----
# RMSE:	0.939488
# NDCG:	0.120513

# %% [markdown]
# #### NMF
# Similar to SVD, works with implicit or explicit feedback. One of the early candidates but was one of the lower preforming models

# %%
# Hyperparameters
n_factors = 20
n_epochs = 30

# %%
# Train
nmf = surprise.NMF(random_state=0, n_factors=n_factors, n_epochs=n_epochs, verbose=True)

with Timer() as train_time:
    nmf.fit(trainset)

print(f"Training took {train_time.interval} seconds")
# Out:
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# Processing epoch 20
# Processing epoch 21
# Processing epoch 22
# Processing epoch 23
# Processing epoch 24
# Processing epoch 25
# Processing epoch 26
# Processing epoch 27
# Processing epoch 28
# Processing epoch 29
# Training took 2.376322160999962 seconds

# %%
# View results
predictions = predict(nmf, test, usercol='userID', itemcol='itemID')

predictions.head()
# Out:
#    userID  itemID  prediction
# 0     535     699    3.828133
# 1     732     332    4.750383
# 2     559     385    4.036553
# 3     378     473    3.459776
# 4      23      28    4.354365

# %%
# Test
with Timer() as test_time:
    all_predictions = compute_ranking_predictions(nmf, train, usercol='userID', itemcol='itemID', remove_seen=True)
    
print(f"Testing took {test_time.interval} seconds")
# Out:
# Testing took 24.18148979199998 seconds

# %%
# Evaluate
eval_rmse = rmse(test, predictions)
eval_ndcg = ndcg_at_k(test, all_predictions, col_prediction='prediction', k=k)

print("NMF (Surprise) Top@10 results:")
print('----')
print("RMSE:\t%f" % eval_rmse)
print("NDCG:\t%f" % eval_ndcg)
# Out:
# NMF (Surprise) Top@10 results:
# ----
# RMSE:	1.025525
# NDCG:	0.049988

# %%
# Out:
# 100%|██████████| 4.81k/4.81k [00:02<00:00, 1.99kKB/s]

# %%
data
# Out:
#        user_id  item_id  rating
# 0          196      242     3.0
# 1          186      302     3.0
# 2           22      377     1.0
# 3          244       51     2.0
# 4          166      346     1.0
# ...        ...      ...     ...
# 99995      880      476     3.0
# 99996      716      204     5.0
# 99997      276     1090     1.0
# 99998       13      225     2.0
# 99999       12      203     3.0
#
# [100000 rows x 3 columns]

# %%
from model import EASE
from recommenders.datasets import movielens

data = movielens.load_pandas_df(size='100k', header=['user_id', 'item_id', 'rating'])

ease_model = EASE()

ease_model.fit(data)

predictions = ease_model.predict_single(2, 10)
predictions
# Out:
# 100%|██████████| 4.81k/4.81k [00:01<00:00, 3.00kKB/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 10
#       6 ease_model = EASE()
#       8 ease_model.fit(data)
# ---> 10 predictions = ease_model.predict_single([2], 10)
#      11 predictions
#
# File ~/projects/cs-project/packages/node-server/recommendation/model.py:57, in EASE.predict_single(self, u, k)
#      55 scores = self.X[u, :].multiply(self.B)
#      56 # scores = self.X[u, :] @ self.B
# ---> 57 return np.argsort(-scores)[:, :k]
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed
